# %% [markdown]
# <a href="https://colab.research.google.com/github/BetoRdz01/Analitica-de-Datos/blob/main/Extracci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b77db254-9142-41b6-b79f-b8afe3d24d00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b77db254-9142-41b6-b79f-b8afe3d24d00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving file.csv to file (1).csv

# %%
import pandas as pd
df= pd.read_csv("file.csv")
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4554 entries, 0 to 4553
# Data columns (total 7 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Periodo                                          4554 non-null   int64
#  1   Trimestre                                        4554 non-null   int64
#  2   Entidad_Federativa                               4554 non-null   object
#  3   Sexo                                             4554 non-null   object
#  4   Poblacion_ocupada_en_la_industria_manufacturera  4554 non-null   object
#  5   Poblaci n_ocupada                                4554 non-null   object
#  6   Tasa_de_ocupaci n_en_la_industria_manufacturera  4554 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 249.2+ KB
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0        2005          1           Nacional  Hombres
# ...

# %%
filtro1 = df[df["Sexo"] == "Mujeres"]
filtro1
# Out:
#       Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 1        2005          1             Nacional  Mujeres
# 3        2005          1       Aguascalientes  Mujeres
# 5        2005          1      Baja California  Mujeres
# 7        2005          1  Baja California Sur  Mujeres
# 9        2005          1             Campeche  Mujeres
# ...       ...        ...                  ...      ...
# 4545     2022          1           Tamaulipas  Mujeres
# 4547     2022          1             Tlaxcala  Mujeres
# 4549     2022          1             Veracruz  Mujeres
# 4551     2022          1              Yucat n  Mujeres
# 4553     2022          1            Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 1                                            2690296          14843275
# 3                                              28430            145656
# 5                                             103697            398911
# ...

# %%
filtro2  = df[df["Periodo"] == 2022]
filtro2
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 4488     2022          1           Nacional  Hombres
# 4489     2022          1           Nacional  Mujeres
# 4490     2022          1     Aguascalientes  Hombres
# 4491     2022          1     Aguascalientes  Mujeres
# 4492     2022          1    Baja California  Hombres
# ...       ...        ...                ...      ...
# 4549     2022          1           Veracruz  Mujeres
# 4550     2022          1            Yucat n  Hombres
# 4551     2022          1            Yucat n  Mujeres
# 4552     2022          1          Zacatecas  Hombres
# 4553     2022          1          Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 4488                                         5757843          33997934
# 4489                                         3564843          22081189
# 4490                                           97926            379297
# ...

# %%
filtro3 = filtro1[df["Entidad_Federativa"] == "Puebla"]
filtro3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 43       2005          1             Puebla  Mujeres
# 109      2005          2             Puebla  Mujeres
# 175      2005          3             Puebla  Mujeres
# 241      2005          4             Puebla  Mujeres
# 307      2006          1             Puebla  Mujeres
# ...       ...        ...                ...      ...
# 4267     2021          1             Puebla  Mujeres
# 4333     2021          2             Puebla  Mujeres
# 4399     2021          3             Puebla  Mujeres
# 4465     2021          4             Puebla  Mujeres
# 4531     2022          1             Puebla  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# ...

# %%
filtro4 = df.iloc[ [1000, 2000, 3000], :]
filtro4
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 1000     2008          4           Coahuila  Hombres
# 2000     2012          3            Durango  Hombres
# 3000     2016          2             M xico  Hombres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 1000                                          162606            694961
# 2000                                           76715            433701
# 3000                                          807150           4305995
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 1000                        23.397859740000000000000
# 2000                        17.688453570000000000000
# 3000                         18.74479650000000000000

# %%
filtro5 = df.iloc[50:550, :]
filtro5
# Out:
#      Periodo  Trimestre Entidad_Federativa     Sexo  \
# 50      2005          1            Sinaloa  Hombres
# 51      2005          1            Sinaloa  Mujeres
# 52      2005          1             Sonora  Hombres
# 53      2005          1             Sonora  Mujeres
# 54      2005          1            Tabasco  Hombres
# ..       ...        ...                ...      ...
# 545     2007          1          Chihuahua  Mujeres
# 546     2007          1   Ciudad de M xico  Hombres
# 547     2007          1   Ciudad de M xico  Mujeres
# 548     2007          1            Durango  Hombres
# 549     2007          1            Durango  Mujeres
#
#     Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 50                                            77990            749476
# 51                                            53206            399694
# 52                                            91143            651067
# ...

# %%
filtro6 = df.iloc[ : , 2:5]
filtro6
# Out:
#      Entidad_Federativa     Sexo  \
# 0              Nacional  Hombres
# 1              Nacional  Mujeres
# 2        Aguascalientes  Hombres
# 3        Aguascalientes  Mujeres
# 4       Baja California  Hombres
# ...                 ...      ...
# 4549           Veracruz  Mujeres
# 4550            Yucat n  Hombres
# 4551            Yucat n  Mujeres
# 4552          Zacatecas  Hombres
# 4553          Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera
# 0                                            4384907
# 1                                            2690296
# 2                                              56407
# 3                                              28430
# 4                                             167651
# ...                                              ...
# 4549                                          107640
# 4550                                          101992
# 4551                                           82759
# ...

# %%
#Para que se cumplan dos filtros se usa el simbolo "&", y para decir este u otro filtro se usa "|"
filtro7 =df[(df["Periodo"] >= 2006) | (df["Sexo"] == "Mujeres")]
filtro7
# Out:
#       Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 1        2005          1             Nacional  Mujeres
# 3        2005          1       Aguascalientes  Mujeres
# 5        2005          1      Baja California  Mujeres
# 7        2005          1  Baja California Sur  Mujeres
# 9        2005          1             Campeche  Mujeres
# ...       ...        ...                  ...      ...
# 4549     2022          1             Veracruz  Mujeres
# 4550     2022          1              Yucat n  Hombres
# 4551     2022          1              Yucat n  Mujeres
# 4552     2022          1            Zacatecas  Hombres
# 4553     2022          1            Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 1                                            2690296          14843275
# 3                                              28430            145656
# 5                                             103697            398911
# ...

# %%
#Convertir un archivo a csv
filtro7.to_csv("ActividadFiltros.csv")

from google.colab import files

files.download("ActividadFiltros.csv")
